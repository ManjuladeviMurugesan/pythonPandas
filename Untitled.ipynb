# %%
import pandas as pd
df = pd.read_csv("powerbi.csv")
print(df)
# Out:
#            Model     Name                         Email Director  \
# 0         Basic     James    James Tony@Sample_Demo.com   Morris
# 1         Basic      John     John Tony@Sample_Demo.com   Morris
# 2         Basic    Robert   Robert Tony@Sample_Demo.com   Morris
# 3         Basic   Michael  Michael Tony@Sample_Demo.com   Morris
# 4         Basic   William  William Tony@Sample_Demo.com   Morris
# 5         Basic     David    David Tony@Sample_Demo.com   Morris
# 6         Basic   Richard  Richard Tony@Sample_Demo.com   Morris
# 7         Basic   Charles  Charles Tony@Sample_Demo.com   Morris
# 8         Basic    Joseph   Joseph Tony@Sample_Demo.com   Morris
# 9         Basic    Thomas   Thomas Tony@Sample_Demo.com   Morris
# 10        Basic    Edward   Edward Tony@Sample_Demo.com   Morris
# 11        Basic    Daniel   Daniel Tony@Sample_Demo.com   Morris
# 12        Basic      Paul     Paul Tony@Sample_Demo.com   Morris
# ...

# %%
import pandas as pd
df = pd.read_csv("powerbi.csv")
print(df.to_string())
# Out:
#            Model     Name                         Email Director Senior Manager Please select your Manager Name:  Please enter your Employee ID: Please enter your Dell Email ID:  Gender         Job Level Attendance    Team  Attendance Status  Salary      Date Month Quarter  Bonus
# 0         Basic     James    James Tony@Sample_Demo.com   Morris            Dan                              Dan                         8645382            James Tony@Sample.com    Male         Executive    Present  Team 4                  1   10000  2/1/2022   Feb      Q1    500
# 1         Basic      John     John Tony@Sample_Demo.com   Morris          Lewis                            Lewis                         8645383             John Tony@Sample.com    Male  Senior Executive     Absent  Team 5                  0   11000  2/1/2022   Feb      Q1    550
# ...

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
print(pd.options.display.min_rows)
# Out:
# 10
